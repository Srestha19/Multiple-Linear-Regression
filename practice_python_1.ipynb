# %% [markdown]
# <a href="https://colab.research.google.com/github/Srestha19/Multiple-Linear-Regression/blob/master/practice_python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find the length of a given string without using the len() function

s= str(input("Enter the string "))
length=0
for i in s:
  length+=1
print(length)
# Out:
# Enter the string Srestah
# 7

# %%
# Extract username from a given email.
# Eg if the email is nitish24singh@gmail.com
# then the username should be nitish24singh

email= input("Enter email: ")

ind = email.index('@')
print(email[:ind])
# Out:
# Enter email: srestha@gmal
# srestha

# %%
# Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s= input("Enter the string: ")

s.count('h')
# Out:
# Enter the string: srestha
# 1

# %%
counter = 0
for i in s:
  if i =='h':
    counter+=1
print(counter)
# Out:
# 1

# %%
# Write a program which can remove a particular character from a string.
s= input("Enter the string: ")
deletion = input("What you want to del? ")

new_str =''

for i in s:
  if i != deletion:
    new_str = new_str + i

print(new_str)
# Out:
# Enter the string: Srestha
# What you want to del? s
# Sretha

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam
s = input('enter the string')
flag = True
for i in range(0,len(s)//2,1):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')
# Out:
# enter the stringabba
# Palindrome

# %%
# Write a program to count the number of words in a string without split()
s = 'Srestha'
l= []
for i in s:
  l.append(i)

len(l)
# Out:
# 7

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string ')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# enter the string srestha
# Srestha

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
# Out:
# enter the number12345
# 12345
# <class 'str'>
